# %% [markdown]
# # 3. Model Training
#
# This notebook demonstrates training CNN models for patch classification.
#
# ## Experiments
#
# We run several binary classification experiments:
#
# | # | Name | Classes | Difficulty |
# |---|------|---------|------------|
# | 1 | Normal vs Any Tumor | 0 vs (1,2,3) | Medium |
# | 2 | Normal vs Pure Tumor | 0 vs 3 | Easy |
# | 3 | Slide Context | 0 vs 1 | Hard |
# | 4 | Normal vs Actual Tumor | 0 vs (2,3) | Medium |
# | 5 | Normal vs Boundary | 0 vs 2 | Hard |

# %%
# REMOVE THIS CODE ONCE WE@RE HAPPY ALL IS WORKING WELL: sys.path.insert() will work well once this all in repo
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# navigate to correct directory
# %cd /content/drive/MyDrive/new_work/Projects/Camelyon16/camelyon16-pathology
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/new_work/Projects/Camelyon16/camelyon16-pathology

# %%
# Install requirements

# !apt-get -y install openslide-tools
# !pip -q install -r requirements.txt
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# openslide-tools is already the newest version (3.4.1+dfsg-5build1).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

from config import DEFAULT_CONFIG
from src.models import run_binary_experiment, MODEL_REGISTRY

# Set seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# %%
# Path to pre-generated 4-class stain-normalised dataset
DATASET_PATH = '/content/drive/MyDrive/new_work/Projects/pathovis_project/data/camelyon16_4class_stain_normalised'

# %% [markdown]
# ## 3.1 Model Architectures
#
# We have three model architectures available:

# %%
# Available models
print("Available models:")
for name, builder in MODEL_REGISTRY.items():
    model = builder()
    print(f"  {name}: {model.count_params():,} parameters")
    del model
# Out:
# Available models:
#   simple: 65,825 parameters
#   subtle: 390,593 parameters
#   attention: 390,850 parameters

# %%
# Visualise simple model architecture
from src.models.architectures import build_simple_cnn

model = build_simple_cnn()
model.summary()
# Out:
# Model: "simple_cnn"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 112, 112, 16)   │         1,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 112, 112, 16)   │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_11 (Activation)      │ (None, 112, 112, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 112, 112, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_12 (Conv2D)              │ (None, 56, 56, 32)     │        12,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 56, 56, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_12 (Activation)      │ (None, 56, 56, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 56, 56, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 28, 28, 64)     │        51,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 28, 28, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_13 (Activation)      │ (None, 28, 28, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 28, 28, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_3      │ (None, 64)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 65,825 (257.13 KB)
#  Trainable params: 65,601 (256.25 KB)
#  Non-trainable params: 224 (896.00 B)

# %% [markdown]
# ## 3.2 Experiment 2: Normal vs Pure Tumor (Baseline)
#
# This is the easiest experiment - distinguishing clearly normal tissue from pure tumor.

# %%
# Settings to ease RAM usage
DEFAULT_CONFIG.training.max_patches_per_chunk = 400
DEFAULT_CONFIG.training.cycle_length = 2
DEFAULT_CONFIG.training.normalise_patches = True

# Run baseline experiment
results_baseline = run_binary_experiment(
    dataset_path=DATASET_PATH,
    experiment_type=2,  # Normal vs Pure Tumor
    model_name='subtle',
    epochs=15,
    learning_rate=1e-5
)

print(f"\nBaseline Results:")
print(f"  Accuracy: {results_baseline['results']['accuracy']:.1%}")
print(f"  AUC: {results_baseline['results']['auc']:.3f}")
# Out:
# ============================================================
# EXPERIMENT: Normal vs Pure Tumor
# ============================================================
# Model: subtle
# Mapping: {0: ['normal_from_normal'], 1: ['pure_tumor']}
# ✓ No slide leakage (180 train, 74 val slides)
# Train: 92 chunks, Val: 40 chunks
#   Training chunks: 52 normal, 40 tumor
# Loading validation patches with pre-allocation...
#   Found 22 normal chunks, 18 tumor chunks
#     normal: chunk 5/22, 450 patches loaded
#     normal: chunk 10/22, 900 patches loaded
#     normal: chunk 15/22, 1350 patches loaded
#     normal: chunk 20/22, 1800 patches loaded
#     normal: chunk 22/22, 1980 patches loaded
#     tumor: chunk 5/18, 555 patches loaded
#     tumor: chunk 10/18, 1110 patches loaded
#     tumor: chunk 15/18, 1665 patches loaded
#     tumor: chunk 18/18, 1998 patches loaded
#   Loaded: 1980 normal, 1998 tumor patches
#   Balanced: 1980 samples per class (3960 total)
#   Created cached validation dataset: 3960 samples
# Steps: 1150 train, 124 val
#
# Model: 390,593 parameters
# Training: 1150 steps/epoch, 15 max epochs
# Epoch 1/15
# 1150/1150 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.6502 - auc: 0.7055 - loss: 0.6304
# Epoch 1: val_loss improved from inf to 0.89173, saving model to ./models/normal_vs_pure_tumor.keras
# 1150/1150 ━━━━━━━━━━━━━━━━━━━━ 476s 352ms/step - accuracy: 0.6502 - auc: 0.7055 - loss: 0.6304 - val_accuracy: 0.5765 - val_auc: 0.8554 - val_loss: 0.8917 - learning_rate: 1.0000e-05
# Epoch 2/15
# 1150/1150 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.7872 - auc: 0.8404 - loss: 0.5097
# Epoch 2: val_loss improved from 0.89173 to 0.75105, saving model to ./models/normal_vs_pure_tumor.keras
# 1150/1150 ━━━━━━━━━━━━━━━━━━━━ 403s 351ms/step - accuracy: 0.7872 - auc: 0.8404 - loss: 0.5097 - val_accuracy: 0.6722 - val_auc: 0.8606 - val_loss: 0.7510 - learning_rate: 1.0000e-05
# Epoch 3/15
# 1150/1150 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.8136 - auc: 0.8737 - loss: 0.4506
# Epoch 3: val_loss improved from 0.75105 to 0.43764, saving model to ./models/normal_vs_pure_tumor.keras
# 1150/1150 ━━━━━━━━━━━━━━━━━━━━ 400s 348ms/step - accuracy: 0.8136 - auc: 0.8737 - loss: 0.4506 - val_accuracy: 0.8121 - val_auc: 0.8892 - val_loss: 0.4376 - learning_rate: 1.0000e-05
# Epoch 4/15
# 1150/1150 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.8183 - auc: 0.8771 - loss: 0.4383
# Epoch 4: val_loss did not improve from 0.43764
# 1150/1150 ━━━━━━━━━━━━━━━━━━━━ 403s 351ms/step - accuracy: 0.8183 - auc: 0.8771 - loss: 0.4382 - val_accuracy: 0.8197 - val_auc: 0.8818 - val_loss: 0.4692 - learning_rate: 1.0000e-05
# Epoch 5/15
# 1150/1150 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.8265 - auc: 0.8900 - loss: 0.4169
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
#
# Epoch 5: val_loss did not improve from 0.43764
# 1150/1150 ━━━━━━━━━━━━━━━━━━━━ 394s 343ms/step - accuracy: 0.8265 - auc: 0.8900 - loss: 0.4169 - val_accuracy: 0.8220 - val_auc: 0.8928 - val_loss: 0.4531 - learning_rate: 1.0000e-05
# Epoch 6/15
# 1150/1150 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.8198 - auc: 0.8886 - loss: 0.4219
# Epoch 6: val_loss did not improve from 0.43764
# 1150/1150 ━━━━━━━━━━━━━━━━━━━━ 402s 349ms/step - accuracy: 0.8198 - auc: 0.8886 - loss: 0.4219 - val_accuracy: 0.7798 - val_auc: 0.9061 - val_loss: 0.5348 - learning_rate: 5.0000e-06
# Epoch 6: early stopping
# Restoring model weights from the end of the best epoch: 3.
#
# ==================================================
# Evaluating: Normal vs Pure Tumor
# ==================================================
# Optimal threshold: 0.337
# Samples: 3,960
# Accuracy: 82.1%
# AUC: 0.889
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       0.86      0.77      0.81      1980
#        Tumor       0.79      0.87      0.83      1980
#
#     accuracy                           0.82      3960
#    macro avg       0.83      0.82      0.82      3960
# weighted avg       0.83      0.82      0.82      3960
# Saved model metadata to models/normal_vs_pure_tumor.json
#
# Baseline Results:
#   Accuracy: 82.1%
#   AUC: 0.889

# %%
# Cleanup memory before next experiment
import gc
import tensorflow as tf

# Clear Keras session (releases GPU memory and graph)
tf.keras.backend.clear_session()

# Force garbage collection
gc.collect()

print("Memory cleared")
# Out:
# Memory cleared

# %% [markdown]
# ## 3.3 Experiment 3: Slide Context Detection (Hard)
#
# Can we distinguish normal tissue from normal slides vs normal tissue from tumor slides?
#
# This tests whether there are subtle changes in "normal" tissue when a tumor is present nearby.

# %%
# Cleanup memory before next experiment
tf.keras.backend.clear_session()
gc.collect()
print("Memory cleared")
# Out:
# Memory cleared

# %%
# Settings to ease RAM usage
DEFAULT_CONFIG.training.max_patches_per_chunk = 400
DEFAULT_CONFIG.training.cycle_length = 2
DEFAULT_CONFIG.training.normalise_patches = True

# Run slide context experiment with subtle model
results_context = run_binary_experiment(
    dataset_path=DATASET_PATH,
    experiment_type=3,  # Slide Context
    model_name='subtle',  # Use subtle model for fine-grained features
    epochs=15,
    learning_rate=1e-5
)

print(f"\nSlide Context Results:")
print(f"  Accuracy: {results_context['results']['accuracy']:.1%}")
print(f"  AUC: {results_context['results']['auc']:.3f}")
# Out:
# ============================================================
# EXPERIMENT: Slide Context Detection
# ============================================================
# Model: subtle
# Mapping: {0: ['normal_from_normal'], 1: ['normal_from_tumor']}
# ✓ No slide leakage (181 train, 77 val slides)
# Train: 91 chunks, Val: 39 chunks
#   Training chunks: 52 normal, 39 tumor
# Loading validation patches with pre-allocation...
#   Found 22 normal chunks, 17 tumor chunks
#     normal: chunk 5/22, 450 patches loaded
#     normal: chunk 10/22, 900 patches loaded
#     normal: chunk 15/22, 1350 patches loaded
#     normal: chunk 20/22, 1800 patches loaded
#     normal: chunk 22/22, 1980 patches loaded
#     tumor: chunk 5/17, 585 patches loaded
#     tumor: chunk 10/17, 1170 patches loaded
#     tumor: chunk 15/17, 1755 patches loaded
#     tumor: chunk 17/17, 1989 patches loaded
#   Loaded: 1980 normal, 1989 tumor patches
#   Balanced: 1980 samples per class (3960 total)
#   Created cached validation dataset: 3960 samples
# Steps: 1137 train, 124 val
#
# Model: 390,593 parameters
# Training: 1137 steps/epoch, 15 max epochs
# Epoch 1/15
# 1137/1137 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.5022 - auc: 0.5043 - loss: 0.7574
# Epoch 1: val_loss improved from inf to 0.69056, saving model to ./models/slide_context_detection.keras
# 1137/1137 ━━━━━━━━━━━━━━━━━━━━ 445s 337ms/step - accuracy: 0.5022 - auc: 0.5043 - loss: 0.7574 - val_accuracy: 0.5283 - val_auc: 0.5791 - val_loss: 0.6906 - learning_rate: 1.0000e-05
# Epoch 2/15
# 1137/1137 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.5290 - auc: 0.5416 - loss: 0.7083
# Epoch 2: val_loss did not improve from 0.69056
# 1137/1137 ━━━━━━━━━━━━━━━━━━━━ 400s 352ms/step - accuracy: 0.5290 - auc: 0.5416 - loss: 0.7083 - val_accuracy: 0.5111 - val_auc: 0.5676 - val_loss: 0.7299 - learning_rate: 1.0000e-05
# Epoch 3/15
# 1137/1137 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step - accuracy: 0.5566 - auc: 0.5867 - loss: 0.6897
# Epoch 3: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
#
# Epoch 3: val_loss did not improve from 0.69056
# 1137/1137 ━━━━━━━━━━━━━━━━━━━━ 393s 346ms/step - accuracy: 0.5566 - auc: 0.5867 - loss: 0.6897 - val_accuracy: 0.5558 - val_auc: 0.6329 - val_loss: 0.7240 - learning_rate: 1.0000e-05
# Epoch 4/15
# 1137/1137 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.5454 - auc: 0.5679 - loss: 0.7082
# Epoch 4: val_loss did not improve from 0.69056
# 1137/1137 ━━━━━━━━━━━━━━━━━━━━ 395s 348ms/step - accuracy: 0.5454 - auc: 0.5679 - loss: 0.7081 - val_accuracy: 0.5275 - val_auc: 0.6371 - val_loss: 0.7552 - learning_rate: 5.0000e-06
# Epoch 4: early stopping
# Restoring model weights from the end of the best epoch: 1.
#
# ==================================================
# Evaluating: Slide Context Detection
# ==================================================
# Optimal threshold: 0.538
# Samples: 3,960
# Accuracy: 56.5%
# AUC: 0.579
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       0.56      0.64      0.60      1980
#        Tumor       0.58      0.49      0.53      1980
#
#     accuracy                           0.57      3960
#    macro avg       0.57      0.57      0.56      3960
# weighted avg       0.57      0.57      0.56      3960
# Saved model metadata to models/slide_context_detection.json
#
# Slide Context Results:
#   Accuracy: 56.5%
#   AUC: 0.579

# %%
# Cleanup memory before visualisation
tf.keras.backend.clear_session()
gc.collect()
print("Memory cleared")
# Out:
# Memory cleared

# %% [markdown]
# ## 3.4 Experiment 5: Normal vs Boundary (Hard)
#
# Can we detect the transition zone between normal and tumor tissue?

# %%
DEFAULT_CONFIG.training.normalise_patches = True

# Run boundary detection experiment
results_boundary = run_binary_experiment(
    dataset_path=DATASET_PATH,
    experiment_type=5,  # Normal vs Boundary
    model_name='subtle',
    epochs=15,
    learning_rate=1e-5
)

print(f"\nBoundary Detection Results:")
print(f"  Accuracy: {results_boundary['results']['accuracy']:.1%}")
print(f"  AUC: {results_boundary['results']['auc']:.3f}")
# Out:
# ============================================================
# EXPERIMENT: Normal vs Boundary
# ============================================================
# Model: subtle
# Mapping: {0: ['normal_from_normal'], 1: ['boundary_tumor']}
# ✓ No slide leakage (179 train, 75 val slides)
# Train: 100 chunks, Val: 44 chunks
#   Training chunks: 51 normal, 49 tumor
# Loading validation patches with pre-allocation...
#   Found 23 normal chunks, 21 tumor chunks
#     normal: chunk 5/23, 430 patches loaded
#     normal: chunk 10/23, 860 patches loaded
#     normal: chunk 15/23, 1290 patches loaded
#     normal: chunk 20/23, 1720 patches loaded
#     normal: chunk 23/23, 1978 patches loaded
#     tumor: chunk 5/21, 475 patches loaded
#     tumor: chunk 10/21, 950 patches loaded
#     tumor: chunk 15/21, 1425 patches loaded
#     tumor: chunk 20/21, 1900 patches loaded
#     tumor: chunk 21/21, 1995 patches loaded
#   Loaded: 1978 normal, 1995 tumor patches
#   Balanced: 1978 samples per class (3956 total)
#   Created cached validation dataset: 3956 samples
# Steps: 1250 train, 124 val
#
# Model: 390,593 parameters
# Training: 1250 steps/epoch, 15 max epochs
# Epoch 1/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step - accuracy: 0.5351 - auc: 0.5489 - loss: 0.7485
# Epoch 1: val_loss improved from inf to 0.67856, saving model to ./models/normal_vs_boundary.keras
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 439s 307ms/step - accuracy: 0.5351 - auc: 0.5490 - loss: 0.7485 - val_accuracy: 0.6292 - val_auc: 0.6766 - val_loss: 0.6786 - learning_rate: 1.0000e-05
# Epoch 2/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.6259 - auc: 0.6668 - loss: 0.6608
# Epoch 2: val_loss improved from 0.67856 to 0.62806, saving model to ./models/normal_vs_boundary.keras
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 358s 286ms/step - accuracy: 0.6259 - auc: 0.6668 - loss: 0.6608 - val_accuracy: 0.6484 - val_auc: 0.7093 - val_loss: 0.6281 - learning_rate: 1.0000e-05
# Epoch 3/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.6320 - auc: 0.6766 - loss: 0.6514
# Epoch 3: val_loss did not improve from 0.62806
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 375s 300ms/step - accuracy: 0.6320 - auc: 0.6766 - loss: 0.6513 - val_accuracy: 0.5882 - val_auc: 0.7309 - val_loss: 0.7363 - learning_rate: 1.0000e-05
# Epoch 4/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.6350 - auc: 0.6835 - loss: 0.6481
# Epoch 4: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
#
# Epoch 4: val_loss did not improve from 0.62806
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 378s 303ms/step - accuracy: 0.6350 - auc: 0.6835 - loss: 0.6481 - val_accuracy: 0.5907 - val_auc: 0.7454 - val_loss: 0.7143 - learning_rate: 1.0000e-05
# Epoch 5/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.6188 - auc: 0.6549 - loss: 0.6670
# Epoch 5: val_loss improved from 0.62806 to 0.59706, saving model to ./models/normal_vs_boundary.keras
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 365s 292ms/step - accuracy: 0.6188 - auc: 0.6550 - loss: 0.6670 - val_accuracy: 0.6777 - val_auc: 0.7437 - val_loss: 0.5971 - learning_rate: 5.0000e-06
# Epoch 6/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.6318 - auc: 0.6787 - loss: 0.6512
# Epoch 6: val_loss improved from 0.59706 to 0.58808, saving model to ./models/normal_vs_boundary.keras
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 362s 290ms/step - accuracy: 0.6318 - auc: 0.6787 - loss: 0.6512 - val_accuracy: 0.6944 - val_auc: 0.7554 - val_loss: 0.5881 - learning_rate: 5.0000e-06
# Epoch 7/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - accuracy: 0.6300 - auc: 0.6768 - loss: 0.6502
# Epoch 7: val_loss did not improve from 0.58808
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 371s 297ms/step - accuracy: 0.6301 - auc: 0.6768 - loss: 0.6501 - val_accuracy: 0.6729 - val_auc: 0.7411 - val_loss: 0.6001 - learning_rate: 5.0000e-06
# Epoch 8/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.6643 - auc: 0.7224 - loss: 0.6158
# Epoch 8: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
#
# Epoch 8: val_loss did not improve from 0.58808
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 360s 288ms/step - accuracy: 0.6643 - auc: 0.7224 - loss: 0.6158 - val_accuracy: 0.6155 - val_auc: 0.7478 - val_loss: 0.6692 - learning_rate: 5.0000e-06
# Epoch 9/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.6432 - auc: 0.6931 - loss: 0.6380
# Epoch 9: val_loss did not improve from 0.58808
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 363s 290ms/step - accuracy: 0.6432 - auc: 0.6931 - loss: 0.6380 - val_accuracy: 0.6183 - val_auc: 0.7492 - val_loss: 0.6731 - learning_rate: 2.5000e-06
# Epoch 9: early stopping
# Restoring model weights from the end of the best epoch: 6.
#
# ==================================================
# Evaluating: Normal vs Boundary
# ==================================================
# Optimal threshold: 0.498
# Samples: 3,956
# Accuracy: 69.6%
# AUC: 0.755
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       0.70      0.68      0.69      1978
#        Tumor       0.69      0.71      0.70      1978
#
#     accuracy                           0.70      3956
#    macro avg       0.70      0.70      0.70      3956
# weighted avg       0.70      0.70      0.70      3956
# Saved model metadata to models/normal_vs_boundary.json
#
# Boundary Detection Results:
#   Accuracy: 69.6%
#   AUC: 0.755

# %% [markdown]
# ## 3.5 Compare Results

# %%
import matplotlib.pyplot as plt

experiments = [
    ('Normal vs Pure Tumor', results_baseline),
    ('Slide Context', results_context),
    ('Normal vs Boundary', results_boundary)
]

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

names = [e[0] for e in experiments]
accuracies = [e[1]['results']['accuracy'] for e in experiments]
aucs = [e[1]['results']['auc'] for e in experiments]

x = np.arange(len(names))
width = 0.35

axes[0].bar(x, accuracies)
axes[0].set_ylabel('Accuracy')
axes[0].set_xticks(x)
axes[0].set_xticklabels(names, rotation=15, ha='right')
axes[0].set_ylim(0.5, 1.0)
axes[0].axhline(0.5, color='gray', linestyle='--', label='Random')

axes[1].bar(x, aucs)
axes[1].set_ylabel('AUC')
axes[1].set_xticks(x)
axes[1].set_xticklabels(names, rotation=15, ha='right')
axes[1].set_ylim(0.5, 1.0)
axes[1].axhline(0.5, color='gray', linestyle='--', label='Random')

plt.suptitle('Experiment Comparison')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3.6 Test Set Evaluation
#
# Evaluate each trained model on the held-out test set to check for generalisation beyond the validation split.

# %%
from src.models import evaluate_on_test_set, load_model_metadata

# %%
TEST_DATASET_PATH = '/content/drive/MyDrive/new_work/Projects/pathovis_project/data/camelyon16_test_stain_normalised'

# Load saved models from disk
exp2_model = keras.models.load_model('./models/normal_vs_pure_tumor.keras')
exp3_model = keras.models.load_model('./models/slide_context_detection.keras')
exp5_model = keras.models.load_model('./models/normal_vs_boundary.keras')

print("Models loaded successfully!")
print(f"Exp 2: {exp2_model.count_params():,} params")
print(f"Exp 3: {exp3_model.count_params():,} params")
print(f"Exp 5: {exp5_model.count_params():,} params")

# Load thresholds and normalisation settings from metadata (saved during training)
exp2_meta = load_model_metadata('./models/normal_vs_pure_tumor.keras')
exp3_meta = load_model_metadata('./models/slide_context_detection.keras')
exp5_meta = load_model_metadata('./models/normal_vs_boundary.keras')

exp2_threshold = exp2_meta['threshold']
exp3_threshold = exp3_meta['threshold']
exp5_threshold = exp5_meta['threshold']

# Get normalise_patches settings (default to True)
exp2_normalise = exp2_meta.get('normalise_patches', True)
exp3_normalise = exp3_meta.get('normalise_patches', True)
exp5_normalise = exp5_meta.get('normalise_patches', True)

print(f"\nThresholds from validation:")
print(f"  Exp 2 (Normal vs Pure Tumor): {exp2_threshold:.3f}")
print(f"  Exp 3 (Slide Context): {exp3_threshold:.3f}")
print(f"  Exp 5 (Normal vs Boundary): {exp5_threshold:.3f}")

print(f"\nNormalisation settings from training:")
print(f"  Exp 2: {exp2_normalise}")
print(f"  Exp 3: {exp3_normalise}")
print(f"  Exp 5: {exp5_normalise}")

# Experiment 2: Normal vs Pure Tumor
print("\n" + "=" * 60)
print("TEST SET EVALUATION: Experiment 2 - Normal vs Pure Tumor")
print("=" * 60)
exp2_class_mapping = {0: ['normal_from_normal'], 1: ['pure_tumor']}
exp2_test_results = evaluate_on_test_set(exp2_model, TEST_DATASET_PATH, exp2_class_mapping, "exp2", threshold=exp2_threshold, normalise=exp2_normalise)
print(f"Threshold (from val): {exp2_threshold:.3f}")
print(f"Accuracy: {exp2_test_results['accuracy']:.1%}")
print(f"AUC: {exp2_test_results['auc']:.3f}")
print(exp2_test_results['report'])

# Experiment 3: Slide Context Detection
print("=" * 60)
print("TEST SET EVALUATION: Experiment 3 - Slide Context Detection")
print("=" * 60)
exp3_class_mapping = {0: ['normal_from_normal'], 1: ['normal_from_tumor']}
exp3_test_results = evaluate_on_test_set(exp3_model, TEST_DATASET_PATH, exp3_class_mapping, "exp3", threshold=exp3_threshold, normalise=exp3_normalise)
print(f"Threshold (from val): {exp3_threshold:.3f}")
print(f"Accuracy: {exp3_test_results['accuracy']:.1%}")
print(f"AUC: {exp3_test_results['auc']:.3f}")
print(exp3_test_results['report'])

# Experiment 5: Normal vs Boundary
print("=" * 60)
print("TEST SET EVALUATION: Experiment 5 - Normal vs Boundary")
print("=" * 60)
exp5_class_mapping = {0: ['normal_from_normal'], 1: ['boundary_tumor']}
exp5_test_results = evaluate_on_test_set(exp5_model, TEST_DATASET_PATH, exp5_class_mapping, "exp5", threshold=exp5_threshold, normalise=exp5_normalise)
print(f"Threshold (from val): {exp5_threshold:.3f}")
print(f"Accuracy: {exp5_test_results['accuracy']:.1%}")
print(f"AUC: {exp5_test_results['auc']:.3f}")
print(exp5_test_results['report'])

# %%
import matplotlib.pyplot as plt
import numpy as np

# Validation results from metadata (saved during training)
val_accs = [exp2_meta['accuracy'], exp3_meta['accuracy'], exp5_meta['accuracy']]
val_aucs = [exp2_meta['auc'], exp3_meta['auc'], exp5_meta['auc']]

# Test results from evaluation
test_accs = [exp2_test_results['accuracy'], exp3_test_results['accuracy'], exp5_test_results['accuracy']]
test_aucs = [exp2_test_results['auc'], exp3_test_results['auc'], exp5_test_results['auc']]

experiments = ['Exp 2: Normal vs\nPure Tumor', 'Exp 3: Slide\nContext', 'Exp 5: Normal vs\nBoundary']

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

x = np.arange(len(experiments))
width = 0.35

# Accuracy comparison
axes[0].bar(x - width/2, val_accs, width, label='Validation', color='steelblue')
axes[0].bar(x + width/2, test_accs, width, label='Test', color='darkorange')
axes[0].set_ylabel('Accuracy')
axes[0].set_title('Validation vs Test Accuracy')
axes[0].set_xticks(x)
axes[0].set_xticklabels(experiments)
axes[0].legend()
axes[0].set_ylim(0.5, 1.0)
for i, (v, t) in enumerate(zip(val_accs, test_accs)):
    axes[0].text(i - width/2, v + 0.02, f'{v:.1%}', ha='center', fontsize=9)
    axes[0].text(i + width/2, t + 0.02, f'{t:.1%}', ha='center', fontsize=9)

# AUC comparison
axes[1].bar(x - width/2, val_aucs, width, label='Validation', color='steelblue')
axes[1].bar(x + width/2, test_aucs, width, label='Test', color='darkorange')
axes[1].set_ylabel('AUC')
axes[1].set_title('Validation vs Test AUC')
axes[1].set_xticks(x)
axes[1].set_xticklabels(experiments)
axes[1].legend()
axes[1].set_ylim(0.5, 1.0)
for i, (v, t) in enumerate(zip(val_aucs, test_aucs)):
    axes[1].text(i - width/2, v + 0.02, f'{v:.3f}', ha='center', fontsize=9)
    axes[1].text(i + width/2, t + 0.02, f'{t:.3f}', ha='center', fontsize=9)

plt.tight_layout()
plt.savefig('val_vs_test_comparison.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Summary
#
# Key findings:
# 1. **Pure tumor detection is easy** - Clear visual differences enable high accuracy
# 2. **Slide context detection is hard** - Subtle changes in "normal" tissue are difficult to detect
# 3. **Boundary detection varies** - Performance depends on how we define "boundary"
#
# ## Next Steps
#
# To improve hard experiments:
# - **More data** - Larger datasets help with subtle patterns
# - **Better augmentation** - Colour normalisation, stain augmentation
# - **Pretrained models** - Transfer learning from ImageNet or pathology models
# - **Multi-instance learning** - Consider multiple patches per slide
